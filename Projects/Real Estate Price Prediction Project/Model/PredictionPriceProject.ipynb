# %%
import pandas as pd

df1 = pd.read_csv("Bengaluru_House_Data.csv")
df1.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from util import predict_price
#       3 import pandas as pd
#       5 df1 = pd.read_csv("Bengaluru_House_Data.csv")
#
# ModuleNotFoundError: No module named 'util'

# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams["figure.figsize"] = (20, 10)

# %%
df1.shape
# Out:
# (13320, 9)

# %%
df1.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
df2 = df1.drop(['availability', 'society', 'area_type', 'balcony'], axis = 'columns')
df2.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
df2.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
df3 = df2.dropna()
df3.isnull().sum()

df3
# Out:
#                        location       size total_sqft  bath   price
# 0      Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1              Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2                   Uttarahalli      3 BHK       1440   2.0   62.00
# 3            Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                      Kothanur      2 BHK       1200   2.0   51.00
# ...                         ...        ...        ...   ...     ...
# 13315                Whitefield  5 Bedroom       3453   4.0  231.00
# 13316             Richards Town      4 BHK       3600   5.0  400.00
# 13317     Raja Rajeshwari Nagar      2 BHK       1141   2.0   60.00
# 13318           Padmanabhanagar      4 BHK       4689   4.0  488.00
# 13319              Doddathoguru      1 BHK        550   1.0   17.00
#
# [13246 rows x 5 columns]

# %%
df3.shape
# Out:
# (13246, 5)

# %%
df3['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
df3['bhk'] = df3['size'].apply(lambda x: int(x.split(' ')[0]))
# Out:
# C:\Users\Smoke Nandos\AppData\Local\Temp\ipykernel_31208\2222900254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['bhk'] = df3['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
df3.head()
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                  Kothanur      2 BHK       1200   2.0   51.00    2

# %%
df3['bhk'].unique()
# Out:
# array([ 2,  4,  3,  6,  1,  8,  7,  5, 11,  9, 27, 10, 19, 16, 43, 14, 12,
#        13, 18], dtype=int64)

# %%
df3[df3.bhk > 18]
# Out:
#                        location        size total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II      27 BHK       8000  27.0  230.0   27
# 3379             1Hanuman Nagar      19 BHK       2000  16.0  490.0   19
# 4684                Munnekollal  43 Bedroom       2400  40.0  660.0   43

# %%
df3.total_sqft.unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
df3[~df3['total_sqft'].apply(is_float)]
# Out:
#                  location   size   total_sqft  bath    price  bhk
# 30              Yelahanka  4 BHK  2100 - 2850   4.0  186.000    4
# 122                Hebbal  4 BHK  3067 - 8156   4.0  477.000    4
# 137    8th Phase JP Nagar  2 BHK  1042 - 1105   2.0   54.005    2
# 165              Sarjapur  2 BHK  1145 - 1340   2.0   43.490    2
# 188              KR Puram  2 BHK  1015 - 1540   2.0   56.800    2
# ...                   ...    ...          ...   ...      ...  ...
# 12975          Whitefield  2 BHK   850 - 1060   2.0   38.190    2
# 12990      Talaghattapura  3 BHK  1804 - 2273   3.0  122.000    3
# 13059              Harlur  2 BHK  1200 - 1470   2.0   72.760    2
# 13265               Hoodi  2 BHK  1133 - 1384   2.0   59.135    2
# 13299          Whitefield  4 BHK  2830 - 2882   5.0  154.500    4
#
# [190 rows x 6 columns]

# %%
def convert_sqft_to_num(x):
    tokens = x.split('-')
    if len(tokens) == 2:
        return (float(tokens[0]) + float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
convert_sqft_to_num('3998')
# Out:
# 3998.0

# %%
convert_sqft_to_num('1015 - 1540')
# Out:
# 1277.5

# %%
convert_sqft_to_num('4125Perch')

# %%
convert_sqft_to_num('34.46Sq. Meter')

# %%
df4 = df3.copy()
df4['total_sqft'] = df4['total_sqft'].apply(convert_sqft_to_num)
df4.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2

# %%
df4.loc[549]
# Out:
# location      Hennur Road
# size                2 BHK
# total_sqft         1317.5
# bath                  2.0
# price               63.77
# bhk                     2
# Name: 549, dtype: object

# %%
(1195 + 1440)/2
# Out:
# 1317.5

# %%
df4.head(4)
# Out:
#                    location       size  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3

# %%
df5 = df4.copy()
df5['price_per_sqft'] = df5['price']*100000 /df5['total_sqft']
df5.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000

# %%
len(df5.location.unique())
# Out:
# 1304

# %%
df5.location = df5.location.apply(lambda x: x.strip())
location_stats = df5.groupby('location')['location'].agg('count').sort_values(ascending = False)
location_stats
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
len(location_stats[location_stats <= 20])
# Out:
# 1150

# %%
location_stats_less_than_20 = location_stats[location_stats <= 20]
location_stats_less_than_20
# Out:
# location
# Poorna Pragna Layout     20
# Sanjay nagar             20
# Yelachenahalli           20
# Binny Pete               20
# HBR Layout               20
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1150, dtype: int64

# %%
len(df5.location.unique())
# Out:
# 1293

# %%
df5.location = df5.location.apply(lambda x: 'other' if x in location_stats_less_than_20 else x)
len(df5.location.unique())
# Out:
# 144

# %%
df5.head(10)
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1                     other  4 Bedroom      2600.0   5.0  120.00    4
# 2               Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                  Kothanur      2 BHK      1200.0   2.0   51.00    2
# 5                Whitefield      2 BHK      1170.0   2.0   38.00    2
# 6          Old Airport Road      4 BHK      2732.0   4.0  204.00    4
# 7              Rajaji Nagar      4 BHK      3300.0   4.0  600.00    4
# 8              Marathahalli      3 BHK      1310.0   3.0   63.25    3
# 9                     other  6 Bedroom      1020.0   6.0  370.00    6
#
#    price_per_sqft
# 0     3699.810606
# 1     4615.384615
# 2     4305.555556
# 3     6245.890861
# 4     4250.000000
# 5     3247.863248
# 6     7467.057101
# 7    18181.818182
# 8     4828.244275
# 9    36274.509804

# %%
df5[df5.total_sqft/df5.bhk < 275].head()
# Out:
#       location       size  total_sqft  bath  price  bhk  price_per_sqft
# 9        other  6 Bedroom      1020.0   6.0  370.0    6    36274.509804
# 45  HSR Layout  8 Bedroom       600.0   9.0  200.0    8    33333.333333
# 58       other  6 Bedroom      1407.0   4.0  150.0    6    10660.980810
# 68       other  8 Bedroom      1350.0   7.0   85.0    8     6296.296296
# 70       other  3 Bedroom       500.0   3.0  100.0    3    20000.000000

# %%
df5.shape
# Out:
# (13246, 7)

# %%
df6 = df5[~(df5.total_sqft/df5.bhk < 275)]
df6.shape
# Out:
# (12564, 7)

# %%
df6
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1                         other  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13315                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13316                     other      4 BHK      3600.0   5.0  400.00    4
# 13317     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13318           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13319              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0         3699.810606
# 1         4615.384615
# 2         4305.555556
# 3         6245.890861
# 4         4250.000000
# ...               ...
# 13315     6689.834926
# 13316    11111.111111
# 13317     5258.545136
# 13318    10407.336319
# 13319     3090.909091
#
# [12564 rows x 7 columns]

# %%
df6.price_per_sqft.describe()
# Out:
# count     12518.000000
# mean       6325.331446
# std        4190.538419
# min         267.829813
# 25%        4210.526316
# 50%        5297.655271
# 75%        6938.702520
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
import numpy as np

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft > (m-st)) & (subdf.price_per_sqft <= (m+st))]
        df_out = pd.concat([df_out, reduced_df], ignore_index = True)
    return df_out

# %%
df7 = remove_pps_outliers(df6)
df7.shape
# Out:
# (10517, 7)

# %%
import matplotlib.pyplot as plt

# %%
def plot_scatter_chart(df, location):
    bhk2 = df[(df.location == location) & (df.bhk == 2)]
    bhk3 = df[(df.location == location) & (df.bhk == 3)]
    matplotlib.rcParams['figure.figsize'] = (15, 10)

    plt.scatter(bhk2.total_sqft, bhk2.price, color = 'orange', label = '2 BHK', s = 50)
    plt.scatter(bhk3.total_sqft, bhk3.price, marker = '+', color = 'blue', label = '3 BHK',  s = 50)
    plt.xlabel('Total Square Feet Area')
    plt.ylabel('Price')

    plt.title(location)
    plt.legend()

# %%
plot_scatter_chart(df7, 'Yelahanka')

# %%
plot_scatter_chart(df7, 'Hebbal')

# %%
# Removing outliers:

def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }

        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk - 1)
            if stats and stats['count'] > 5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft < (stats['mean'])].index.values)
    return df.drop(exclude_indices, axis = 'index')

# %%
df8 = remove_bhk_outliers(df7)
df8.shape
# Out:
# (7015, 7)

# %%
plot_scatter_chart(df8, "Yelahanka")

# %%
plot_scatter_chart(df8, "Hebbal")

# %%
matplotlib.rcParams["figure.figsize"] = (20, 10)
plt.hist(df8.price_per_sqft, rwidth = 0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df8.bath.unique()
# Out:
# array([ 3.,  5.,  4.,  2.,  8.,  1.,  6.,  7.,  9., 27., 12., 16., 13.])

# %%
df8[df8.bath > 10]
# Out:
#      location    size  total_sqft  bath  price  bhk  price_per_sqft
# 7522    other  27 BHK      8000.0  27.0  230.0   27     2875.000000
# 7890    other  10 BHK     12000.0  12.0  525.0   10     4375.000000
# 8035    other  16 BHK     10000.0  16.0  550.0   16     5500.000000
# 9120    other  11 BHK      6000.0  12.0  150.0   11     2500.000000
# 9293    other  10 BHK      4000.0  12.0  160.0   10     4000.000000
# 9633    other  13 BHK      5425.0  13.0  275.0   13     5069.124424

# %%
plt.hist(df8.bath, rwidth = 0.8)
plt.xlabel("Number of bathrooms")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
df8[df8.bath > df8.bhk + 2]
# Out:
#          location       size  total_sqft  bath   price  bhk  price_per_sqft
# 5873  Thanisandra      3 BHK      1806.0   6.0   116.0    3     6423.034330
# 7768        other      6 BHK     11338.0   9.0  1000.0    6     8819.897689
# 9997        other  4 Bedroom      7000.0   8.0   450.0    4     6428.571429

# %%
df9 = df8[df8.bath < df8.bhk + 2]
df9.shape
# Out:
# (6935, 7)

# %%
df10 = df9.drop(['price_per_sqft', 'size'], axis = 'columns')
df10.head(5)
# Out:
#              location  total_sqft  bath  price  bhk
# 1  1st Phase JP Nagar      1875.0   3.0  167.0    3
# 2  1st Phase JP Nagar      1500.0   5.0   85.0    5
# 3  1st Phase JP Nagar      2065.0   4.0  210.0    3
# 5  1st Phase JP Nagar      2059.0   3.0  225.0    3
# 6  1st Phase JP Nagar      1394.0   2.0  100.0    2

# %%
dummies = pd.get_dummies(df10.location)
dummies
# Out:
#        1st Phase JP Nagar  2nd Stage Nagarbhavi  5th Phase JP Nagar  \
# 1                    True                 False               False
# 2                    True                 False               False
# 3                    True                 False               False
# 5                    True                 False               False
# 6                    True                 False               False
# ...                   ...                   ...                 ...
# 10509               False                 False               False
# 10512               False                 False               False
# 10513               False                 False               False
# 10515               False                 False               False
# 10516               False                 False               False
#
#        6th Phase JP Nagar  7th Phase JP Nagar  8th Phase JP Nagar  \
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 5                   False               False               False
# 6                   False               False               False
# ...                   ...                 ...                 ...
# 10509               False               False               False
# 10512               False               False               False
# 10513               False               False               False
# 10515               False               False               False
# 10516               False               False               False
#
#        9th Phase JP Nagar  Abbigere  Akshaya Nagar  Ambalipura  ...  \
# 1                   False     False          False       False  ...
# 2                   False     False          False       False  ...
# 3                   False     False          False       False  ...
# 5                   False     False          False       False  ...
# 6                   False     False          False       False  ...
# ...                   ...       ...            ...         ...  ...
# 10509               False     False          False       False  ...
# 10512               False     False          False       False  ...
# 10513               False     False          False       False  ...
# 10515               False     False          False       False  ...
# 10516               False     False          False       False  ...
#
#        Uttarahalli  Varthur  Vidyaranyapura  Vijayanagar  Vittasandra  \
# 1            False    False           False        False        False
# 2            False    False           False        False        False
# 3            False    False           False        False        False
# 5            False    False           False        False        False
# 6            False    False           False        False        False
# ...            ...      ...             ...          ...          ...
# 10509        False    False           False        False        False
# 10512        False    False           False        False        False
# 10513        False    False           False        False        False
# 10515        False    False           False        False        False
# 10516        False    False           False        False        False
#
#        Whitefield  Yelahanka  Yelahanka New Town  Yeshwanthpur  other
# 1           False      False               False         False  False
# 2           False      False               False         False  False
# 3           False      False               False         False  False
# 5           False      False               False         False  False
# 6           False      False               False         False  False
# ...           ...        ...                 ...           ...    ...
# 10509       False      False               False         False   True
# 10512       False      False               False         False   True
# 10513       False      False               False         False   True
# 10515       False      False               False         False   True
# 10516       False      False               False         False   True
#
# [6935 rows x 144 columns]

# %%
df11 = pd.concat([df10, dummies.drop('other', axis = 'columns')], axis = 'columns')
df11.head(4)
# Out:
#              location  total_sqft  bath  price  bhk  1st Phase JP Nagar  \
# 1  1st Phase JP Nagar      1875.0   3.0  167.0    3                True
# 2  1st Phase JP Nagar      1500.0   5.0   85.0    5                True
# 3  1st Phase JP Nagar      2065.0   4.0  210.0    3                True
# 5  1st Phase JP Nagar      2059.0   3.0  225.0    3                True
#
#    2nd Stage Nagarbhavi  5th Phase JP Nagar  6th Phase JP Nagar  \
# 1                 False               False               False
# 2                 False               False               False
# 3                 False               False               False
# 5                 False               False               False
#
#    7th Phase JP Nagar  ...  Ulsoor  Uttarahalli  Varthur  Vidyaranyapura  \
# 1               False  ...   False        False    False           False
# 2               False  ...   False        False    False           False
# 3               False  ...   False        False    False           False
# 5               False  ...   False        False    False           False
#
#    Vijayanagar  Vittasandra  Whitefield  Yelahanka  Yelahanka New Town  \
# 1        False        False       False      False               False
# 2        False        False       False      False               False
# 3        False        False       False      False               False
# 5        False        False       False      False               False
#
#    Yeshwanthpur
# 1         False
# 2         False
# 3         False
# 5         False
#
# [4 rows x 148 columns]

# %%
df12 = df11.drop('location', axis = 'columns')
df12.head(3)
# Out:
#    total_sqft  bath  price  bhk  1st Phase JP Nagar  2nd Stage Nagarbhavi  \
# 1      1875.0   3.0  167.0    3                True                 False
# 2      1500.0   5.0   85.0    5                True                 False
# 3      2065.0   4.0  210.0    3                True                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  7th Phase JP Nagar  \
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
#
#    8th Phase JP Nagar  ...  Ulsoor  Uttarahalli  Varthur  Vidyaranyapura  \
# 1               False  ...   False        False    False           False
# 2               False  ...   False        False    False           False
# 3               False  ...   False        False    False           False
#
#    Vijayanagar  Vittasandra  Whitefield  Yelahanka  Yelahanka New Town  \
# 1        False        False       False      False               False
# 2        False        False       False      False               False
# 3        False        False       False      False               False
#
#    Yeshwanthpur
# 1         False
# 2         False
# 3         False
#
# [3 rows x 147 columns]

# %%
df12.shape
# Out:
# (6935, 147)

# %%
X = df12.drop('price', axis = 'columns')
X.head(3)
# Out:
#    total_sqft  bath  bhk  1st Phase JP Nagar  2nd Stage Nagarbhavi  \
# 1      1875.0   3.0    3                True                 False
# 2      1500.0   5.0    5                True                 False
# 3      2065.0   4.0    3                True                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  7th Phase JP Nagar  \
# 1               False               False               False
# 2               False               False               False
# 3               False               False               False
#
#    8th Phase JP Nagar  9th Phase JP Nagar  ...  Ulsoor  Uttarahalli  Varthur  \
# 1               False               False  ...   False        False    False
# 2               False               False  ...   False        False    False
# 3               False               False  ...   False        False    False
#
#    Vidyaranyapura  Vijayanagar  Vittasandra  Whitefield  Yelahanka  \
# 1           False        False        False       False      False
# 2           False        False        False       False      False
# 3           False        False        False       False      False
#
#    Yelahanka New Town  Yeshwanthpur
# 1               False         False
# 2               False         False
# 3               False         False
#
# [3 rows x 146 columns]

# %%
y = df12.price
y.head(5)
# Out:
# 1    167.0
# 2     85.0
# 3    210.0
# 5    225.0
# 6    100.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.46, random_state = 9)

# %%
from sklearn.linear_model import LinearRegression
lr_clf = LinearRegression()
lr_clf.fit(X_train, y_train)
lr_clf.score(X_test, y_test)
# Out:
# 0.8502317496632985

# %%
from sklearn.ensemble import RandomForestRegressor

rf_reg = RandomForestRegressor(n_estimators = 50)
rf_reg.fit(X_train, y_train)
rf_reg.score(X_test, y_test)
# Out:
# 0.8168924048379531

# %%
from sklearn.model_selection import KFold
kf = KFold(n_splits = 15)
kf
# Out:
# KFold(n_splits=15, random_state=None, shuffle=False)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import ShuffleSplit

cv = ShuffleSplit(n_splits = 6, test_size = 0.3, random_state = 0)

cross_val_score(LinearRegression(), X, y, cv=cv)
# Out:
# array([0.84251211, 0.80613331, 0.82927281, 0.80341638, 0.77074097,
#        0.83544332])

# %%
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import Lasso
from sklearn.tree import DecisionTreeRegressor

# %%
def find_best_model_using_gridsearchcv(X, y):
    algos = {
        'linear_regression' : {
            'model': LinearRegression(),
            'params': {
                
            }
        },

        'lasso': {
            'model': Lasso(),
            'params': {
                'alpha': [1, 2],
                'selection': ['random', 'cyclic']
            }
        },

        'decision_tree': {
            'model': DecisionTreeRegressor(),
            'params': {
                'criterion' : ['squared_error', 'friedman_mse'],
                'splitter': ['best', 'random']
            }
        }

    }

    scores = []
    cv = ShuffleSplit(n_splits = 5, test_size = 0.2, random_state = 0)
    for algo_name, config in algos.items():
        gs = GridSearchCV(config['model'], config['params'], cv = cv, return_train_score = False)
        gs.fit(X, y)
        scores.append({
            'model': algo_name,
            'best_score': gs.best_score_,
            'best_params': gs.best_params_
    })


    return pd.DataFrame(scores, columns = ['model', 'best_score', 'best_params'])

# %%
find_best_model_using_gridsearchcv(X, y)
# Out:
#                model  best_score  \
# 0  linear_regression    0.813137
# 1              lasso    0.732403
# 2      decision_tree    0.632851
#
#                                          best_params
# 0                                                 {}
# 1                {'alpha': 1, 'selection': 'cyclic'}
# 2  {'criterion': 'friedman_mse', 'splitter': 'ran...

# %%
X.columns
# Out:
# Index(['total_sqft', 'bath', 'bhk', '1st Phase JP Nagar',
#        '2nd Stage Nagarbhavi', '5th Phase JP Nagar', '6th Phase JP Nagar',
#        '7th Phase JP Nagar', '8th Phase JP Nagar', '9th Phase JP Nagar',
#        ...
#        'Ulsoor', 'Uttarahalli', 'Varthur', 'Vidyaranyapura', 'Vijayanagar',
#        'Vittasandra', 'Whitefield', 'Yelahanka', 'Yelahanka New Town',
#        'Yeshwanthpur'],
#       dtype='object', length=146)

# %%
df12
# Out:
#        total_sqft  bath  price  bhk  1st Phase JP Nagar  2nd Stage Nagarbhavi  \
# 1          1875.0   3.0  167.0    3                True                 False
# 2          1500.0   5.0   85.0    5                True                 False
# 3          2065.0   4.0  210.0    3                True                 False
# 5          2059.0   3.0  225.0    3                True                 False
# 6          1394.0   2.0  100.0    2                True                 False
# ...           ...   ...    ...  ...                 ...                   ...
# 10509       812.0   1.0   26.0    1               False                 False
# 10512      1200.0   2.0  140.0    2               False                 False
# 10513      1015.0   2.0   60.0    2               False                 False
# 10515      1805.0   3.0  134.0    3               False                 False
# 10516      3600.0   5.0  400.0    4               False                 False
#
#        5th Phase JP Nagar  6th Phase JP Nagar  7th Phase JP Nagar  \
# 1                   False               False               False
# 2                   False               False               False
# 3                   False               False               False
# 5                   False               False               False
# 6                   False               False               False
# ...                   ...                 ...                 ...
# 10509               False               False               False
# 10512               False               False               False
# 10513               False               False               False
# 10515               False               False               False
# 10516               False               False               False
#
#        8th Phase JP Nagar  ...  Ulsoor  Uttarahalli  Varthur  Vidyaranyapura  \
# 1                   False  ...   False        False    False           False
# 2                   False  ...   False        False    False           False
# 3                   False  ...   False        False    False           False
# 5                   False  ...   False        False    False           False
# 6                   False  ...   False        False    False           False
# ...                   ...  ...     ...          ...      ...             ...
# 10509               False  ...   False        False    False           False
# 10512               False  ...   False        False    False           False
# 10513               False  ...   False        False    False           False
# 10515               False  ...   False        False    False           False
# 10516               False  ...   False        False    False           False
#
#        Vijayanagar  Vittasandra  Whitefield  Yelahanka  Yelahanka New Town  \
# 1            False        False       False      False               False
# 2            False        False       False      False               False
# 3            False        False       False      False               False
# 5            False        False       False      False               False
# 6            False        False       False      False               False
# ...            ...          ...         ...        ...                 ...
# 10509        False        False       False      False               False
# 10512        False        False       False      False               False
# 10513        False        False       False      False               False
# 10515        False        False       False      False               False
# 10516        False        False       False      False               False
#
#        Yeshwanthpur
# 1             False
# 2             False
# 3             False
# 5             False
# 6             False
# ...             ...
# 10509         False
# 10512         False
# 10513         False
# 10515         False
# 10516         False
#
# [6935 rows x 147 columns]

# %%
np.where(X.columns == '8th Phase JP Nagar')[0][0]
# Out:
# 8

# %%
def predict_price(location, sqft, bath, bhk):
    loc_index = np.where(X.columns == location)[0][0]
    
    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk

    if loc_index >= 0:
        x[loc_index] = 1
    return lr_clf.predict([x])[0]

# %%
predict_price('Ulsoor', 3000, 4, 5)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 259.4733029288608

# %%
predict_price('Varthur', 4500, 6, 6)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 335.1423948770537

# %%
predict_price('Varthur', 4500, 9, 9)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 313.7236529674552

# %%
predict_price('Indira Nagar', 1500, 3, 3)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 235.4141139579794

# %%
predict_price('Indira Nagar', 1500, 15, 3)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 198.613016631829

# %%
predict_price('Indira Nagar', 1500, 3, 9)
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 210.97717880185775

# %%
import pickle

# %%
with open('df11', 'wb') as f:
    pickle.dump(df11, f)

# %%
with open('df11', 'rb') as f:
    mp = pickle.load(f)

# %%
import joblib

# %%
with open('banglore_home_prices_model.pickle', 'wb') as f:
    pickle.dump(lr_clf, f)

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in X.columns]

}

with open("columns.json", "w") as f:
    f.write(json.dumps(columns))

# %%
predict_price(model, X_train.columns, [1000, 2, 2, 0, 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 predict_price(model, X_train.columns, [1000, 2, 2, 0, 1])
#
# NameError: name 'predict_price' is not defined
